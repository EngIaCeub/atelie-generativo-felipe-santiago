# %% [markdown]
# # 01 — Dataset e captions
#
# Scaffold executável a ser completado pelo Codex conforme o runbook e os portões humanos.

# %% [markdown]
# ## Ambiente e configuração
#
# Instalar dependências, carregar config e verificar GPU/arquivos.

# %%
# TODO: implementar e executar; não inventar outputs.
pass

# %% [markdown]
# ## Auditoria de imagens e proveniência
#
# Validar nomes, resolução, licenças e correspondência com fontes.csv.

# %%
# TODO: implementar e executar; não inventar outputs.
pass

# %% [markdown]
# ## Rascunhos BLIP
#
# Gerar captions com status rascunho; não promover automaticamente para revisada.

# %%
# TODO: implementar e executar; não inventar outputs.
pass

# %% [markdown]
# ## Revisão humana
#
# Carregar captions confirmadas pela equipe e verificar token do estilo.

# %%
# TODO: implementar e executar; não inventar outputs.
pass

# %% [markdown]
# ## Exportação
#
# Gerar metadata.jsonl e relatório de integridade do dataset.

# %%
# TODO: implementar e executar; não inventar outputs.
pass
